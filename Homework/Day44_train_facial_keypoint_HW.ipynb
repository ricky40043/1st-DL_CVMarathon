# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 0.0079 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00244, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0021 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00244 to 0.00195, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0015 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00195 to 0.00185, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00185
# Epoch 5/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00185 to 0.00183, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00006: val_loss did not improve from 0.00183
# Epoch 7/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00183 to 0.00183, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.8271e-04 - val_loss: 0.0017
#
# Epoch 00008: val_loss improved from 0.00183 to 0.00175, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 8.7153e-04 - val_loss: 0.0017
#
# Epoch 00009: val_loss improved from 0.00175 to 0.00166, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 7.7409e-04 - val_loss: 0.0015
#
# Epoch 00010: val_loss improved from 0.00166 to 0.00152, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 6.9497e-04 - val_loss: 0.0014
#
# Epoch 00011: val_loss improved from 0.00152 to 0.00137, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 6.2863e-04 - val_loss: 0.0013
#
# Epoch 00012: val_loss improved from 0.00137 to 0.00127, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 5.6251e-04 - val_loss: 0.0012
#
# Epoch 00013: val_loss improved from 0.00127 to 0.00116, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 5.2468e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00116 to 0.00110, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 4.8691e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00110
# Epoch 16/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 4.5708e-04 - val_loss: 0.0011
#
# Epoch 00016: val_loss improved from 0.00110 to 0.00108, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 4.4102e-04 - val_loss: 9.9460e-04
#
# Epoch 00017: val_loss improved from 0.00108 to 0.00099, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 4.1011e-04 - val_loss: 0.0010
#
# Epoch 00018: val_loss did not improve from 0.00099
# Epoch 19/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 3.8758e-04 - val_loss: 9.7565e-04
#
# Epoch 00019: val_loss improved from 0.00099 to 0.00098, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 3.7675e-04 - val_loss: 9.6880e-04
#
# Epoch 00020: val_loss improved from 0.00098 to 0.00097, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 3.5570e-04 - val_loss: 9.8579e-04
#
# Epoch 00021: val_loss did not improve from 0.00097
# Epoch 22/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 3.4858e-04 - val_loss: 9.3497e-04
#
# Epoch 00022: val_loss improved from 0.00097 to 0.00093, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 3.3330e-04 - val_loss: 9.2450e-04
#
# Epoch 00023: val_loss improved from 0.00093 to 0.00092, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 3.4348e-04 - val_loss: 9.2279e-04
#
# Epoch 00024: val_loss improved from 0.00092 to 0.00092, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 3.1714e-04 - val_loss: 8.6166e-04
#
# Epoch 00025: val_loss improved from 0.00092 to 0.00086, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 3.1470e-04 - val_loss: 9.0958e-04
#
# Epoch 00026: val_loss did not improve from 0.00086
# Epoch 27/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.9550e-04 - val_loss: 8.8496e-04
#
# Epoch 00027: val_loss did not improve from 0.00086
# Epoch 28/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 2.9322e-04 - val_loss: 9.0941e-04
#
# Epoch 00028: val_loss did not improve from 0.00086
# Epoch 29/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.8683e-04 - val_loss: 9.2250e-04
#
# Epoch 00029: val_loss did not improve from 0.00086
# Epoch 30/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 2.8206e-04 - val_loss: 8.5413e-04
#
# Epoch 00030: val_loss improved from 0.00086 to 0.00085, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.7094e-04 - val_loss: 8.6525e-04
#
# Epoch 00031: val_loss did not improve from 0.00085
# Epoch 32/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 2.6958e-04 - val_loss: 8.5568e-04
#
# Epoch 00032: val_loss did not improve from 0.00085
# Epoch 33/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.6059e-04 - val_loss: 8.5350e-04
#
# Epoch 00033: val_loss improved from 0.00085 to 0.00085, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.5747e-04 - val_loss: 8.4248e-04
#
# Epoch 00034: val_loss improved from 0.00085 to 0.00084, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.5915e-04 - val_loss: 8.2372e-04
#
# Epoch 00035: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 2.4897e-04 - val_loss: 8.1962e-04
#
# Epoch 00036: val_loss improved from 0.00082 to 0.00082, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.4402e-04 - val_loss: 8.8784e-04
#
# Epoch 00037: val_loss did not improve from 0.00082
# Epoch 38/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.4201e-04 - val_loss: 8.3981e-04
#
# Epoch 00038: val_loss did not improve from 0.00082
# Epoch 39/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.3122e-04 - val_loss: 8.3164e-04
#
# Epoch 00039: val_loss did not improve from 0.00082
# Epoch 40/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.3232e-04 - val_loss: 8.0654e-04
#
# Epoch 00040: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.2777e-04 - val_loss: 8.3731e-04
#
# Epoch 00041: val_loss did not improve from 0.00081
# Epoch 42/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.2480e-04 - val_loss: 8.4099e-04
#
# Epoch 00042: val_loss did not improve from 0.00081
# Epoch 43/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.2228e-04 - val_loss: 8.5426e-04
#
# Epoch 00043: val_loss did not improve from 0.00081
# Epoch 44/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 2.1585e-04 - val_loss: 8.0457e-04
#
# Epoch 00044: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 2.2192e-04 - val_loss: 7.7986e-04
#
# Epoch 00045: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 46/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.0995e-04 - val_loss: 8.1391e-04
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.1112e-04 - val_loss: 7.8405e-04
#
# Epoch 00047: val_loss did not improve from 0.00078
# Epoch 48/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.0511e-04 - val_loss: 8.8006e-04
#
# Epoch 00048: val_loss did not improve from 0.00078
# Epoch 49/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 2.0485e-04 - val_loss: 8.6843e-04
#
# Epoch 00049: val_loss did not improve from 0.00078
# Epoch 50/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.9637e-04 - val_loss: 7.8809e-04
#
# Epoch 00050: val_loss did not improve from 0.00078
# Epoch 51/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.9800e-04 - val_loss: 8.2328e-04
#
# Epoch 00051: val_loss did not improve from 0.00078
# Epoch 52/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.9330e-04 - val_loss: 8.2500e-04
#
# Epoch 00052: val_loss did not improve from 0.00078
# Epoch 53/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.9430e-04 - val_loss: 8.1541e-04
#
# Epoch 00053: val_loss did not improve from 0.00078
# Epoch 54/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.8857e-04 - val_loss: 8.4670e-04
#
# Epoch 00054: val_loss did not improve from 0.00078
# Epoch 55/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.9183e-04 - val_loss: 7.8801e-04
#
# Epoch 00055: val_loss did not improve from 0.00078
# Epoch 56/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.9686e-04 - val_loss: 8.3181e-04
#
# Epoch 00056: val_loss did not improve from 0.00078
# Epoch 57/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.8856e-04 - val_loss: 7.5445e-04
#
# Epoch 00057: val_loss improved from 0.00078 to 0.00075, saving model to best_weights.h5
# Epoch 58/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.8275e-04 - val_loss: 8.1961e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.7570e-04 - val_loss: 8.4283e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.7712e-04 - val_loss: 8.0363e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.8327e-04 - val_loss: 8.0360e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.7818e-04 - val_loss: 7.7867e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.6988e-04 - val_loss: 8.0600e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.6970e-04 - val_loss: 8.0247e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.7574e-04 - val_loss: 7.7695e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.7264e-04 - val_loss: 7.7746e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.6750e-04 - val_loss: 8.0993e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.6582e-04 - val_loss: 8.3963e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.6238e-04 - val_loss: 8.0004e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.6380e-04 - val_loss: 8.0987e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.6102e-04 - val_loss: 8.3263e-04
#
# Epoch 00071: val_loss did not improve from 0.00075
# Epoch 72/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.6451e-04 - val_loss: 7.9715e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.5816e-04 - val_loss: 8.0325e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.5523e-04 - val_loss: 7.9621e-04
#
# Epoch 00074: val_loss did not improve from 0.00075
# Epoch 75/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.5460e-04 - val_loss: 8.0085e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
# Epoch 76/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.5313e-04 - val_loss: 8.5093e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.4948e-04 - val_loss: 8.3112e-04
#
# Epoch 00077: val_loss did not improve from 0.00075
# Epoch 78/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4997e-04 - val_loss: 8.0305e-04
#
# Epoch 00078: val_loss did not improve from 0.00075
# Epoch 79/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.4881e-04 - val_loss: 8.1454e-04
#
# Epoch 00079: val_loss did not improve from 0.00075
# Epoch 80/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.4423e-04 - val_loss: 8.1219e-04
#
# Epoch 00080: val_loss did not improve from 0.00075
# Epoch 81/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.4362e-04 - val_loss: 7.7935e-04
#
# Epoch 00081: val_loss did not improve from 0.00075
# Epoch 82/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4639e-04 - val_loss: 7.8807e-04
#
# Epoch 00082: val_loss did not improve from 0.00075
# Epoch 83/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.4337e-04 - val_loss: 7.6938e-04
#
# Epoch 00083: val_loss did not improve from 0.00075
# Epoch 84/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4345e-04 - val_loss: 7.9967e-04
#
# Epoch 00084: val_loss did not improve from 0.00075
# Epoch 85/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.4472e-04 - val_loss: 8.2609e-04
#
# Epoch 00085: val_loss did not improve from 0.00075
# Epoch 86/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.3900e-04 - val_loss: 7.8353e-04
#
# Epoch 00086: val_loss did not improve from 0.00075
# Epoch 87/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.3828e-04 - val_loss: 7.9491e-04
#
# Epoch 00087: val_loss did not improve from 0.00075
# Epoch 88/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.3810e-04 - val_loss: 7.7083e-04
#
# Epoch 00088: val_loss did not improve from 0.00075
# Epoch 89/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.3972e-04 - val_loss: 7.5256e-04
#
# Epoch 00089: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 90/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.4035e-04 - val_loss: 7.7000e-04
#
# Epoch 00090: val_loss did not improve from 0.00075
# Epoch 91/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.3609e-04 - val_loss: 8.1130e-04
#
# Epoch 00091: val_loss did not improve from 0.00075
# Epoch 92/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.3907e-04 - val_loss: 8.0723e-04
#
# Epoch 00092: val_loss did not improve from 0.00075
# Epoch 93/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.4007e-04 - val_loss: 7.9975e-04
#
# Epoch 00093: val_loss did not improve from 0.00075
# Epoch 94/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.3152e-04 - val_loss: 7.8397e-04
#
# Epoch 00094: val_loss did not improve from 0.00075
# Epoch 95/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.3212e-04 - val_loss: 7.9171e-04
#
# Epoch 00095: val_loss did not improve from 0.00075
# Epoch 96/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.2810e-04 - val_loss: 7.7701e-04
#
# Epoch 00096: val_loss did not improve from 0.00075
# Epoch 97/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.2591e-04 - val_loss: 7.6841e-04
#
# Epoch 00097: val_loss did not improve from 0.00075
# Epoch 98/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.2619e-04 - val_loss: 7.6240e-04
#
# Epoch 00098: val_loss did not improve from 0.00075
# Epoch 99/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.2411e-04 - val_loss: 7.9038e-04
#
# Epoch 00099: val_loss did not improve from 0.00075
# Epoch 100/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.2261e-04 - val_loss: 7.5588e-04
#
# Epoch 00100: val_loss did not improve from 0.00075
# Epoch 101/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.2522e-04 - val_loss: 7.9664e-04
#
# Epoch 00101: val_loss did not improve from 0.00075
# Epoch 102/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.2586e-04 - val_loss: 7.6414e-04
#
# Epoch 00102: val_loss did not improve from 0.00075
# Epoch 103/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.2444e-04 - val_loss: 7.7872e-04
#
# Epoch 00103: val_loss did not improve from 0.00075
# Epoch 104/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.2163e-04 - val_loss: 8.0204e-04
#
# Epoch 00104: val_loss did not improve from 0.00075
# Epoch 105/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.2424e-04 - val_loss: 7.6127e-04
#
# Epoch 00105: val_loss did not improve from 0.00075
# Epoch 106/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.3130e-04 - val_loss: 7.7025e-04
#
# Epoch 00106: val_loss did not improve from 0.00075
# Epoch 107/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.2253e-04 - val_loss: 7.8338e-04
#
# Epoch 00107: val_loss did not improve from 0.00075
# Epoch 108/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.1883e-04 - val_loss: 8.0716e-04
#
# Epoch 00108: val_loss did not improve from 0.00075
# Epoch 109/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.1909e-04 - val_loss: 7.5997e-04
#
# Epoch 00109: val_loss did not improve from 0.00075
# Epoch 110/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.1490e-04 - val_loss: 7.7006e-04
#
# Epoch 00110: val_loss did not improve from 0.00075
# Epoch 111/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.1669e-04 - val_loss: 7.8465e-04
#
# Epoch 00111: val_loss did not improve from 0.00075
# Epoch 112/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.1400e-04 - val_loss: 7.6094e-04
#
# Epoch 00112: val_loss did not improve from 0.00075
# Epoch 113/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.1721e-04 - val_loss: 7.7174e-04
#
# Epoch 00113: val_loss did not improve from 0.00075
# Epoch 114/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.1634e-04 - val_loss: 7.8513e-04
#
# Epoch 00114: val_loss did not improve from 0.00075
# Epoch 115/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.1252e-04 - val_loss: 7.9684e-04
#
# Epoch 00115: val_loss did not improve from 0.00075
# Epoch 116/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.1242e-04 - val_loss: 7.8768e-04
#
# Epoch 00116: val_loss did not improve from 0.00075
# Epoch 117/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.0940e-04 - val_loss: 7.8597e-04
#
# Epoch 00117: val_loss did not improve from 0.00075
# Epoch 118/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.1074e-04 - val_loss: 8.1033e-04
#
# Epoch 00118: val_loss did not improve from 0.00075
# Epoch 119/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.1097e-04 - val_loss: 8.0227e-04
#
# Epoch 00119: val_loss did not improve from 0.00075
# Epoch 120/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0690e-04 - val_loss: 7.5715e-04
#
# Epoch 00120: val_loss did not improve from 0.00075
# Epoch 121/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.0839e-04 - val_loss: 7.7674e-04
#
# Epoch 00121: val_loss did not improve from 0.00075
# Epoch 122/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0941e-04 - val_loss: 7.8550e-04
#
# Epoch 00122: val_loss did not improve from 0.00075
# Epoch 123/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.1033e-04 - val_loss: 7.7279e-04
#
# Epoch 00123: val_loss did not improve from 0.00075
# Epoch 124/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0711e-04 - val_loss: 7.9674e-04
#
# Epoch 00124: val_loss did not improve from 0.00075
# Epoch 125/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.0764e-04 - val_loss: 8.4557e-04
#
# Epoch 00125: val_loss did not improve from 0.00075
# Epoch 126/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0365e-04 - val_loss: 7.8698e-04
#
# Epoch 00126: val_loss did not improve from 0.00075
# Epoch 127/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0394e-04 - val_loss: 8.1132e-04
#
# Epoch 00127: val_loss did not improve from 0.00075
# Epoch 128/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0345e-04 - val_loss: 7.9438e-04
#
# Epoch 00128: val_loss did not improve from 0.00075
# Epoch 129/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0800e-04 - val_loss: 7.8251e-04
#
# Epoch 00129: val_loss did not improve from 0.00075
# Epoch 130/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.0181e-04 - val_loss: 7.9905e-04
#
# Epoch 00130: val_loss did not improve from 0.00075
# Epoch 131/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.0047e-04 - val_loss: 7.9144e-04
#
# Epoch 00131: val_loss did not improve from 0.00075
# Epoch 132/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.0056e-04 - val_loss: 8.1588e-04
#
# Epoch 00132: val_loss did not improve from 0.00075
# Epoch 133/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.0050e-04 - val_loss: 7.7783e-04
#
# Epoch 00133: val_loss did not improve from 0.00075
# Epoch 134/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 9.9043e-05 - val_loss: 7.8097e-04
#
# Epoch 00134: val_loss did not improve from 0.00075
# Epoch 135/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0231e-04 - val_loss: 8.1307e-04
#
# Epoch 00135: val_loss did not improve from 0.00075
# Epoch 136/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.0210e-04 - val_loss: 7.6028e-04
#
# Epoch 00136: val_loss did not improve from 0.00075
# Epoch 137/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 9.9168e-05 - val_loss: 7.8912e-04
#
# Epoch 00137: val_loss did not improve from 0.00075
# Epoch 138/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0035e-04 - val_loss: 8.0470e-04
#
# Epoch 00138: val_loss did not improve from 0.00075
# Epoch 139/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 1.0022e-04 - val_loss: 8.3066e-04
#
# Epoch 00139: val_loss did not improve from 0.00075
# Epoch 140/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.5701e-05 - val_loss: 7.9099e-04
#
# Epoch 00140: val_loss did not improve from 0.00075
# Epoch 141/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 9.9689e-05 - val_loss: 7.7319e-04
#
# Epoch 00141: val_loss did not improve from 0.00075
# Epoch 142/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.8510e-05 - val_loss: 7.6151e-04
#
# Epoch 00142: val_loss did not improve from 0.00075
# Epoch 143/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 9.5653e-05 - val_loss: 7.5946e-04
#
# Epoch 00143: val_loss did not improve from 0.00075
# Epoch 144/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.3311e-05 - val_loss: 7.7250e-04
#
# Epoch 00144: val_loss did not improve from 0.00075
# Epoch 145/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.4933e-05 - val_loss: 7.7035e-04
#
# Epoch 00145: val_loss did not improve from 0.00075
# Epoch 146/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 9.3225e-05 - val_loss: 7.7234e-04
#
# Epoch 00146: val_loss did not improve from 0.00075
# Epoch 147/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 9.1618e-05 - val_loss: 8.1568e-04
#
# Epoch 00147: val_loss did not improve from 0.00075
# Epoch 148/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.1983e-05 - val_loss: 7.9620e-04
#
# Epoch 00148: val_loss did not improve from 0.00075
# Epoch 149/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 9.3492e-05 - val_loss: 7.6839e-04
#
# Epoch 00149: val_loss did not improve from 0.00075
# Epoch 150/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 9.1642e-05 - val_loss: 7.8740e-04
#
# Epoch 00150: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(20,20))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], points_test[i])

# %%
imgs_test[0][1,5]
# Out:
# 0.7019608

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    h,w=img.shape
    New_img = np.copy(img)
    #影像資料翻轉
    for i in range(0,h):
        for j in range(0,w):
           New_img[i,j] = img[i,w-j-1]
    
    #特徵點資料翻轉    
    New_points = np.copy(points) 
    for i in range(0,30,2):
        New_points[i] = -points[i]
    return New_img,New_points

# %%
flip_img, flip_point = augment_data(imgs_test[0], points_test[0])

fig = plt.figure(figsize=(5,5))

plot_keypoints(flip_img, flip_point)

# %%
# 創建 list
NEW_img_train = []
NEW_point_train = []
trainNum = imgs_train.shape[0];
#把Train的整組資料換過來
for i in range(0,trainNum):
    flip_img, flip_point = augment_data(imgs_train[i], points_train[i])    
    
    # 原始資料
    NEW_img_train.append(imgs_train[i])
    NEW_point_train.append(points_train[i]) 
    
    NEW_img_train.append(flip_img)
    NEW_point_train.append(flip_point) 
    
NEW_img_train = np.array(NEW_img_train)
NEW_point_train = np.array(NEW_point_train)

# %%
# 讀取資料
print("圖像資料:", NEW_img_train.shape, "\n關鍵點資料:", NEW_point_train.shape)
# Out:
# 圖像資料: (4280, 96, 96)
# 關鍵點資料: (4280, 30)

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))
    
    model.add(Conv2D(filters=64, kernel_size=1, activation='relu'))
    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=1, activation='relu'))
    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))
    
    model.add(Conv2D(filters=256, kernel_size=1, activation='relu'))
    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 47, 47, 64)        1088
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 45, 45, 32)        18464
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 22, 22, 128)       4224
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 20, 20, 64)        73792
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 10, 10, 256)       16640
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 128)         295040
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,736,542
# Trainable params: 1,736,542
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=50, verbose=1)
# save the model weights
model.save_weights('HW_weights.h5')
# save the model
model.save('HW_model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/50
# 1712/1712 [==============================] - 20s 12ms/step - loss: 0.0053 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00190, saving model to best_weights.h5
# Epoch 2/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00190 to 0.00190, saving model to best_weights.h5
# Epoch 3/50
# 1712/1712 [==============================] - 18s 11ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss did not improve from 0.00190
# Epoch 4/50
# 1712/1712 [==============================] - 18s 11ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00190 to 0.00189, saving model to best_weights.h5
# Epoch 5/50
# 1712/1712 [==============================] - 20s 12ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00189
# Epoch 6/50
# 1712/1712 [==============================] - 18s 10ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00006: val_loss improved from 0.00189 to 0.00189, saving model to best_weights.h5
# Epoch 7/50
# 1712/1712 [==============================] - 18s 10ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00189 to 0.00182, saving model to best_weights.h5
# Epoch 8/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 0.0010 - val_loss: 0.0019
#
# Epoch 00008: val_loss did not improve from 0.00182
# Epoch 9/50
# 1712/1712 [==============================] - 18s 11ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00009: val_loss improved from 0.00182 to 0.00177, saving model to best_weights.h5
# Epoch 10/50
# 1712/1712 [==============================] - 18s 11ms/step - loss: 9.2237e-04 - val_loss: 0.0017
#
# Epoch 00010: val_loss improved from 0.00177 to 0.00173, saving model to best_weights.h5
# Epoch 11/50
# 1712/1712 [==============================] - 18s 10ms/step - loss: 7.5034e-04 - val_loss: 0.0015
#
# Epoch 00011: val_loss improved from 0.00173 to 0.00148, saving model to best_weights.h5
# Epoch 12/50
# 1712/1712 [==============================] - 18s 11ms/step - loss: 6.3965e-04 - val_loss: 0.0013
#
# Epoch 00012: val_loss improved from 0.00148 to 0.00127, saving model to best_weights.h5
# Epoch 13/50
# 1712/1712 [==============================] - 18s 10ms/step - loss: 5.5104e-04 - val_loss: 0.0012
#
# Epoch 00013: val_loss improved from 0.00127 to 0.00119, saving model to best_weights.h5
# Epoch 14/50
# 1712/1712 [==============================] - 20s 11ms/step - loss: 4.9407e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00119 to 0.00108, saving model to best_weights.h5
# Epoch 15/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 4.5122e-04 - val_loss: 9.9827e-04
#
# Epoch 00015: val_loss improved from 0.00108 to 0.00100, saving model to best_weights.h5
# Epoch 16/50
# 1712/1712 [==============================] - 21s 12ms/step - loss: 4.2013e-04 - val_loss: 9.8095e-04
#
# Epoch 00016: val_loss improved from 0.00100 to 0.00098, saving model to best_weights.h5
# Epoch 17/50
# 1712/1712 [==============================] - 20s 12ms/step - loss: 3.9187e-04 - val_loss: 9.4110e-04
#
# Epoch 00017: val_loss improved from 0.00098 to 0.00094, saving model to best_weights.h5
# Epoch 18/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 3.7763e-04 - val_loss: 9.0431e-04
#
# Epoch 00018: val_loss improved from 0.00094 to 0.00090, saving model to best_weights.h5
# Epoch 19/50
# 1712/1712 [==============================] - 18s 10ms/step - loss: 3.5536e-04 - val_loss: 8.9009e-04
#
# Epoch 00019: val_loss improved from 0.00090 to 0.00089, saving model to best_weights.h5
# Epoch 20/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 3.3773e-04 - val_loss: 8.2118e-04
#
# Epoch 00020: val_loss improved from 0.00089 to 0.00082, saving model to best_weights.h5
# Epoch 21/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 3.2842e-04 - val_loss: 8.5671e-04
#
# Epoch 00021: val_loss did not improve from 0.00082
# Epoch 22/50
# 1712/1712 [==============================] - 18s 10ms/step - loss: 3.1441e-04 - val_loss: 7.8361e-04
#
# Epoch 00022: val_loss improved from 0.00082 to 0.00078, saving model to best_weights.h5
# Epoch 23/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.9719e-04 - val_loss: 7.7363e-04
#
# Epoch 00023: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 24/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.9072e-04 - val_loss: 8.2033e-04
#
# Epoch 00024: val_loss did not improve from 0.00077
# Epoch 25/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.8929e-04 - val_loss: 7.8322e-04
#
# Epoch 00025: val_loss did not improve from 0.00077
# Epoch 26/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.7468e-04 - val_loss: 7.8665e-04
#
# Epoch 00026: val_loss did not improve from 0.00077
# Epoch 27/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.7867e-04 - val_loss: 7.7982e-04
#
# Epoch 00027: val_loss did not improve from 0.00077
# Epoch 28/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.5791e-04 - val_loss: 7.5765e-04
#
# Epoch 00028: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 29/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.5148e-04 - val_loss: 7.7411e-04
#
# Epoch 00029: val_loss did not improve from 0.00076
# Epoch 30/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.5093e-04 - val_loss: 7.9812e-04
#
# Epoch 00030: val_loss did not improve from 0.00076
# Epoch 31/50
# 1712/1712 [==============================] - 20s 12ms/step - loss: 2.4387e-04 - val_loss: 7.4997e-04
#
# Epoch 00031: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 32/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.3534e-04 - val_loss: 7.7118e-04
#
# Epoch 00032: val_loss did not improve from 0.00075
# Epoch 33/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.3805e-04 - val_loss: 7.1924e-04
#
# Epoch 00033: val_loss improved from 0.00075 to 0.00072, saving model to best_weights.h5
# Epoch 34/50
# 1712/1712 [==============================] - 20s 12ms/step - loss: 2.2864e-04 - val_loss: 7.3448e-04
#
# Epoch 00034: val_loss did not improve from 0.00072
# Epoch 35/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.2025e-04 - val_loss: 7.2714e-04
#
# Epoch 00035: val_loss did not improve from 0.00072
# Epoch 36/50
# 1712/1712 [==============================] - 20s 12ms/step - loss: 2.1735e-04 - val_loss: 7.0838e-04
#
# Epoch 00036: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 37/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.1797e-04 - val_loss: 7.3921e-04
#
# Epoch 00037: val_loss did not improve from 0.00071
# Epoch 38/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.2480e-04 - val_loss: 7.4738e-04
#
# Epoch 00038: val_loss did not improve from 0.00071
# Epoch 39/50
# 1712/1712 [==============================] - 18s 10ms/step - loss: 2.1165e-04 - val_loss: 7.7761e-04
#
# Epoch 00039: val_loss did not improve from 0.00071
# Epoch 40/50
# 1712/1712 [==============================] - 20s 12ms/step - loss: 2.0614e-04 - val_loss: 7.1622e-04
#
# Epoch 00040: val_loss did not improve from 0.00071
# Epoch 41/50
# 1712/1712 [==============================] - 18s 11ms/step - loss: 2.0434e-04 - val_loss: 6.8853e-04
#
# Epoch 00041: val_loss improved from 0.00071 to 0.00069, saving model to best_weights.h5
# Epoch 42/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.9522e-04 - val_loss: 7.2735e-04
#
# Epoch 00042: val_loss did not improve from 0.00069
# Epoch 43/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.9361e-04 - val_loss: 6.9222e-04
#
# Epoch 00043: val_loss did not improve from 0.00069
# Epoch 44/50
# 1712/1712 [==============================] - 18s 11ms/step - loss: 1.9173e-04 - val_loss: 7.1729e-04
#
# Epoch 00044: val_loss did not improve from 0.00069
# Epoch 45/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.8769e-04 - val_loss: 7.3201e-04
# Epoch 00045: val_loss did not improve from 0.00069
# Epoch 46/50
# 1712/1712 [==============================] - 20s 12ms/step - loss: 1.8871e-04 - val_loss: 7.0074e-04
#
# Epoch 00046: val_loss did not improve from 0.00069
# Epoch 47/50
# 1712/1712 [==============================] - 18s 11ms/step - loss: 1.8880e-04 - val_loss: 7.1122e-04
#
# Epoch 00047: val_loss did not improve from 0.00069
# Epoch 48/50
# 1712/1712 [==============================] - 18s 11ms/step - loss: 1.8328e-04 - val_loss: 7.1033e-04
#
# Epoch 00048: val_loss did not improve from 0.00069
# Epoch 49/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.7754e-04 - val_loss: 7.4572e-04
#
# Epoch 00049: val_loss did not improve from 0.00069
# Epoch 50/50
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.7687e-04 - val_loss: 7.5409e-04
#
# Epoch 00050: val_loss did not improve from 0.00069

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(20,40))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(50):
    ax = fig.add_subplot(10, 5, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], points_test[i])
